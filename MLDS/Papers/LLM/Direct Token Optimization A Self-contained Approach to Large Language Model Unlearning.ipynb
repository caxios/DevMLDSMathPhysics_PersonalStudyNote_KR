# %% [markdown]
# Direct Token Optimization A Self-contained Approach to Large Language Model Unlearning
# link : https://arxiv.org/html/2510.00125v1

# %% [markdown]
# 이미 훈련된 LLM으로부터 불필요한 정보 내지는 민감한 정보 등을 없애는 방법론에 대한 논문이었음. 내가 원했던 논문은 아니었음
