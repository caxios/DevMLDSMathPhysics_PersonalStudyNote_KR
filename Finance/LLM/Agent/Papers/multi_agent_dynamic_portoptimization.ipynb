# %% [markdown]
# Dynamic Portfolio Optimization with Data-Aware Multi-Agent Reinforcement Learning and Adaptive Risk Control
#
# https://dl.acm.org/doi/pdf/10.1145/3778534.3778676#page=2.90

# %% [markdown]
# Method :
# 각 자산 클래스를 담당하는 에이전트들이, dynamic environmet 하에서 f(volatility, yield, price signal, trade volume)을 이용해 expected return을 극대화하는 상태 st를 도출하는데, 상태는 자산 해당 자산 클래스에서의 i자산에 대한 비중(allocation)을 의미한다. 이때 각각의 에이전트는 강화학습에 기반해 행동한다.
